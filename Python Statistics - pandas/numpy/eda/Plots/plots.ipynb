# %%
# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Command to tell Python to actually display the graphs
# %matplotlib inline

# %%
df = pd.read_csv('Automobile.csv')

# %%
df.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
df.describe(include='all').T
# Out:
#                      count unique     top freq          mean          std  \
# symboling            201.0    NaN     NaN  NaN      0.840796     1.254802
# normalized_losses    201.0    NaN     NaN  NaN    125.189055    33.572966
# make                   201     22  toyota   32           NaN          NaN
# fuel_type              201      2     gas  181           NaN          NaN
# aspiration             201      2     std  165           NaN          NaN
# number_of_doors        201      2    four  114           NaN          NaN
# body_style             201      5   sedan   94           NaN          NaN
# drive_wheels           201      3     fwd  118           NaN          NaN
# engine_location        201      2   front  198           NaN          NaN
# wheel_base           201.0    NaN     NaN  NaN     98.797015     6.066366
# length               201.0    NaN     NaN  NaN    174.200995    12.322175
# width                201.0    NaN     NaN  NaN     65.889055     2.101471
# ...

# %%
sns.histplot(data=df, x='price');

# %%
plt.title('Histogram:Price')
plt.xlim(3000,50000)
plt.ylim(0,70)
plt.xlabel('Price of cars')
plt.ylabel('Frequency')
sns.histplot(data=df, x='price',color='orange');

# %%
df = pd.read_csv('Placement_Data.csv')

# %%
df.head()
# Out:
#   gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0      M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1      M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2      M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3      M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4      M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
#
#   workex  etest_p specialisation  mba_p      status
# 0     No     55.0         Mkt&HR  58.80      Placed
# 1    Yes     86.5        Mkt&Fin  66.28      Placed
# 2     No     75.0        Mkt&Fin  57.80      Placed
# 3     No     66.0         Mkt&HR  59.43  Not Placed
# 4     No     96.8        Mkt&Fin  55.50      Placed

# %%
df.describe().transpose()
# Out:
#           count       mean        std    min     25%   50%     75%    max
# ssc_p     215.0  67.303395  10.827205  40.89  60.600  67.0  75.700  89.40
# hsc_p     215.0  66.333163  10.897509  37.00  60.900  65.0  73.000  97.70
# degree_p  215.0  66.370186   7.358743  50.00  61.000  66.0  72.000  91.00
# etest_p   215.0  72.100558  13.275956  50.00  60.000  71.0  83.500  98.00
# mba_p     215.0  62.278186   5.833385  51.21  57.945  62.0  66.255  77.89

# %%
df[df['status']=='Placed'].value_counts()
# Out:
# gender  ssc_p  ssc_b    hsc_p  hsc_b    hsc_s     degree_p  degree_t   workex  etest_p  specialisation  mba_p  status
# F       59.00  Central  60.00  Others   Commerce  56.00     Comm&Mgmt  No      55.00    Mkt&HR          57.90  Placed    1
# M       68.20  Central  72.80  Central  Commerce  66.60     Comm&Mgmt  Yes     96.00    Mkt&Fin         70.85  Placed    1
#         69.00  Others   60.00  Others   Commerce  65.00     Comm&Mgmt  No      87.55    Mkt&Fin         52.81  Placed    1
#                         65.00  Others   Commerce  57.00     Comm&Mgmt  No      73.00    Mkt&HR          55.80  Placed    1
#         69.60  Central  68.40  Central  Commerce  78.30     Comm&Mgmt  Yes     60.00    Mkt&Fin         63.70  Placed    1
#                                                                                                                         ..
#         52.60  Central  65.58  Others   Science   72.11     Sci&Tech   No      57.60    Mkt&Fin         56.66  Placed    1
# ...

# %%
sns.histplot(data=df, x='status');

# %%
sns.countplot(x='hsc_s',data=df,hue='status');

# %%
sns.countplot(x='hsc_s',data=df);

# %%
sns.scatterplot(data=df, x='etest_p', y='mba_p');

# %%
df.head()
# Out:
#   gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0      M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1      M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2      M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3      M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4      M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
#
#   workex  etest_p specialisation  mba_p      status
# 0     No     55.0         Mkt&HR  58.80      Placed
# 1    Yes     86.5        Mkt&Fin  66.28      Placed
# 2     No     75.0        Mkt&Fin  57.80      Placed
# 3     No     66.0         Mkt&HR  59.43  Not Placed
# 4     No     96.8        Mkt&Fin  55.50      Placed

# %%
sns.scatterplot(data=df, x='hsc_s', y='ssc_b');

# %%
sns.boxplot(data=df,x='degree_p');

# %%
sns.boxplot(data=df, x='degree_p', y='hsc_s') ;

# %%
sns.lineplot(data = df , x = 'ssc_p' , y = 'hsc_p',hue='status');

# %%
sns.lmplot(data = df , x = 'ssc_p' , y = 'hsc_p',hue='status');

# %%
sns.histplot(data=df, x='degree_p', kde=True,hue='status');

# %%
df.head()
# Out:
#   gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0      M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1      M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2      M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3      M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4      M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
#
#   workex  etest_p specialisation  mba_p      status
# 0     No     55.0         Mkt&HR  58.80      Placed
# 1    Yes     86.5        Mkt&Fin  66.28      Placed
# 2     No     75.0        Mkt&Fin  57.80      Placed
# 3     No     66.0         Mkt&HR  59.43  Not Placed
# 4     No     96.8        Mkt&Fin  55.50      Placed

# %%
sns.jointplot(data=df, x='ssc_p', y='status');

# %%
sns.histplot(data=df, x='ssc_p',hue='status');

# %%
sns.jointplot(data=df, x='degree_p', y='ssc_p', kind="hex");
plt.colorbar();

# %%
sns.histplot(data=df, x='etest_p', kde=True);

# %%
df.describe()
# Out:
#             ssc_p       hsc_p    degree_p     etest_p       mba_p
# count  215.000000  215.000000  215.000000  215.000000  215.000000
# mean    67.303395   66.333163   66.370186   72.100558   62.278186
# std     10.827205   10.897509    7.358743   13.275956    5.833385
# min     40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     60.600000   60.900000   61.000000   60.000000   57.945000
# 50%     67.000000   65.000000   66.000000   71.000000   62.000000
# 75%     75.700000   73.000000   72.000000   83.500000   66.255000
# max     89.400000   97.700000   91.000000   98.000000   77.890000

# %%
df.isnull().sum()
# Out:
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# dtype: int64

# %%
df['mba_p'].unique()
# Out:
# array([58.8 , 66.28, 57.8 , 59.43, 55.5 , 51.58, 53.29, 62.14, 61.29,
#        52.21, 60.85, 63.7 , 65.04, 68.63, 54.96, 64.66, 62.54, 67.28,
#        64.08, 77.89, 56.7 , 69.06, 68.81, 63.62, 74.01, 65.33, 57.55,
#        57.69, 64.15, 51.29, 58.32, 62.21, 72.78, 62.77, 62.74, 51.45,
#        55.47, 56.86, 62.56, 66.72, 69.76, 51.21, 62.9 , 69.7 , 66.53,
#        71.63, 54.55, 62.46, 56.11, 62.98, 62.65, 65.49, 71.04, 65.56,
#        52.71, 66.88, 63.59, 57.99, 56.66, 57.24, 62.48, 59.69, 59.5 ,
#        58.78, 57.1 , 58.46, 60.99, 59.24, 68.07, 65.45, 66.94, 68.53,
#        59.75, 67.2 , 67.  , 64.27, 57.65, 59.42, 67.99, 62.35, 70.2 ,
#        60.44, 66.69, 62.  , 76.18, 57.03, 59.08, 64.36, 62.36, 68.03,
#        62.79, 59.47, 55.41, 54.97, 62.16, 64.44, 69.03, 57.31, 64.95,
#        61.31, 65.83, 58.23, 55.3 , 65.69, 73.52, 58.31, 56.09, 54.8 ,
#        60.64, 53.94, 63.08, 55.01, 60.5 , 70.85, 67.05, 70.48, 64.34,
# ...
